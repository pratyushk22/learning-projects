# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df=pd.read_csv("canada_per_capita_income.csv")
df.rename(columns={'per capita income (US$)':'pc_income'}, inplace=True)

# %%
# %matplotlib inline 
#redundant in newer versions of Jupyter notebook
plt.scatter(df.year, df.pc_income, c='red')
plt.xlabel('Year')
plt.ylabel('Per Capita Income')
plt.plot(df.year, reg.predict(df[['year']]), color='blue')

# %%
reg= linear_model.LinearRegression()
reg.fit(df[['year']], df.pc_income)
# Out:
# LinearRegression()

# %%
reg.predict([[2020]])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([41288.69409442])

# %%
reg.coef_
# Out:
# array([828.46507522])

# %%
reg.intercept_
# Out:
# np.float64(-1632210.7578554575)

# %%
y= (reg.coef_)*(3300)+(reg.intercept_)
y
# Out:
# array([1101723.99037949])
